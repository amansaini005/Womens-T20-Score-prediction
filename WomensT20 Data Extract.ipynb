# %% [markdown]
# ## Packages

# %%
import pandas as pd
import numpy as np
import os
from yaml import safe_load
from tqdm import tqdm

# %%
filename =[]
for file in os.listdir('femalet20'):
    filename.append(os.path.join('femalet20', file))

# %%
filename[:5]
# Out:
# ['femalet20/808871.yaml',
#  'femalet20/1208808.yaml',
#  'femalet20/1316643.yaml',
#  'femalet20/1190746.yaml',
#  'femalet20/1289260.yaml']

# %%
cric = pd.DataFrame()
counter = 1
for file in tqdm(filename):
    with open(file, 'r') as f:
        df = pd.json_normalize([safe_load(f)])
        df['match_id'] = counter
        cric = pd.concat([df, cric])
        counter += 1
        
cric
# Out:
# 100%|█████████████████████████████████████████| 692/692 [08:46<00:00,  1.31it/s]
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...               0.91
# 0   [{'1st innings': {'team': 'India', 'deliveries...               0.91
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
# 0   [{'1st innings': {'team': 'England', 'deliveri...               0.92
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Barbados', 'deliver...               0.92
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...               0.91
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...               0.92
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...               0.91
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
#
# ...

# %%
cric.shape
# Out:
# (692, 1729)

# %%
from timeit import default_timer

# %%
beginning = default_timer()
mylist = cric.columns.values.tolist()
ending = default_timer()
print(mylist,"\n")
print((ending - beginning)*1000)
# Out:
# ['innings', 'meta.data_version', 'meta.created', 'meta.revision', 'info.balls_per_over', 'info.city', 'info.dates', 'info.gender', 'info.match_type', 'info.match_type_number', 'info.outcome.result', 'info.outcome.eliminator', 'info.overs', 'info.players.Scotland', 'info.players.Netherlands', 'info.registry.people.AH Maqsood', 'info.registry.people.AJT Dowdalls', 'info.registry.people.AS van Beuge', 'info.registry.people.B de Leede', 'info.registry.people.C de Lange', 'info.registry.people.D Hannema', 'info.registry.people.DT Jukes', 'info.registry.people.HDJ Siegers', 'info.registry.people.IJR Zwilling', 'info.registry.people.J Post', 'info.registry.people.K McGill', 'info.registry.people.KE Bryce', 'info.registry.people.L Jack', 'info.registry.people.M McColl', 'info.registry.people.M Veringmeier', 'info.registry.people.PA Chatterji', 'info.registry.people.R Hassan', 'info.registry.people.R Rijke', 'info.registry.people.RK Willis', 'info.registry.people.RS Glen', 'info.registry.peop
# ...

# %%
#beginning = default_timer()
#my_list = list(cric)
#ending = default_timer()
#print(my_list,"\n")
#print((ending - beginning)*1000)
# Out:
# ['innings', 'meta.data_version', 'meta.created', 'meta.revision', 'info.balls_per_over', 'info.city', 'info.dates', 'info.gender', 'info.match_type', 'info.match_type_number', 'info.outcome.result', 'info.outcome.eliminator', 'info.overs', 'info.players.Scotland', 'info.players.Netherlands', 'info.registry.people.AH Maqsood', 'info.registry.people.AJT Dowdalls', 'info.registry.people.AS van Beuge', 'info.registry.people.B de Leede', 'info.registry.people.C de Lange', 'info.registry.people.D Hannema', 'info.registry.people.DT Jukes', 'info.registry.people.HDJ Siegers', 'info.registry.people.IJR Zwilling', 'info.registry.people.J Post', 'info.registry.people.K McGill', 'info.registry.people.KE Bryce', 'info.registry.people.L Jack', 'info.registry.people.M McColl', 'info.registry.people.M Veringmeier', 'info.registry.people.PA Chatterji', 'info.registry.people.R Hassan', 'info.registry.people.R Rijke', 'info.registry.people.RK Willis', 'info.registry.people.RS Glen', 'info.registry.peop
# ...

# %%
cric.drop(columns = ['meta.data_version','meta.created', 'meta.revision', 'info.balls_per_over',
                    'info.match_type_number', 'info.outcome.result', 'info.outcome.eliminator',
                    'info.players.Scotland', 'info.players.Netherlands', 'info.registry.people.AH Maqsood', 'info.registry.people.AJT Dowdalls', 'info.registry.people.AS van Beuge', 'info.registry.people.B de Leede', 'info.registry.people.C de Lange', 'info.registry.people.D Hannema', 'info.registry.people.DT Jukes', 'info.registry.people.HDJ Siegers', 'info.registry.people.IJR Zwilling', 'info.registry.people.J Post', 'info.registry.people.K McGill', 'info.registry.people.KE Bryce', 'info.registry.people.L Jack', 'info.registry.people.M McColl', 'info.registry.people.M Veringmeier', 'info.registry.people.PA Chatterji', 'info.registry.people.R Hassan', 'info.registry.people.R Rijke', 'info.registry.people.RK Willis', 'info.registry.people.RS Glen', 'info.registry.people.RV Scholes', 'info.registry.people.S Haggo', 'info.registry.people.S Siegers', 'info.registry.people.SJ Bryce', 'info.registry.people.SL Kalis', 'info.registry.people.WPM van Liemt',
                    'info.outcome.winner', 'info.outcome.by.runs', 'info.player_of_match', 'info.players.India', 'info.players.Australia', 'info.registry.people.A Gardner', 'info.registry.people.A Reddy', 'info.registry.people.AA Patil', 'info.registry.people.AJ Healy', 'info.registry.people.BL Mooney', 'info.registry.people.D Hemalatha', 'info.registry.people.DB Sharma', 'info.registry.people.DM Kimmince', 'info.registry.people.EA Perry', 'info.registry.people.EJ Villani', 'info.registry.people.GO Brathwaite', 'info.registry.people.H Kaur', 'info.registry.people.JI Rodrigues', 'info.registry.people.ML Schutt', 'info.registry.people.MM Lanning', 'info.registry.people.NE Bolton', 'info.registry.people.Poonam Yadav', 'info.registry.people.RB Richardson', 'info.registry.people.RL Haynes', 'info.registry.people.RP Yadav', 'info.registry.people.S George', 'info.registry.people.S Mandhana', 'info.registry.people.S Molineux', 'info.registry.people.S Redfern', 'info.registry.people.T Bhatia', 'info.registry.people.TJ Vlaeminck', 'info.registry.people.V Krishnamurthy', 'info.registry.people.WR Knights', 'info.outcome.by.wickets', 'info.players.New Zealand', 'info.registry.people.AC Kerr', 'info.registry.people.AE Satterthwaite', 'info.registry.people.BNJ Oxenford', 'info.registry.people.D Taylor', 'info.registry.people.DM Koch', 'info.registry.people.G Wareham', 'info.registry.people.HNK Jensen', 'info.registry.people.JL Jonassen', 'info.registry.people.KJ Martin', 'info.registry.people.KT Perkins', 'info.registry.people.LMM Tahuhu', 'info.registry.people.LR Down', 'info.registry.people.ML Green', 'info.registry.people.MW Graham-Smith', 'info.registry.people.NJ Carey', 'info.registry.people.RA Mair', 'info.registry.people.RW Stratford', 'info.registry.people.SFM Devine', 'info.registry.people.SW Bates', 'info.neutral_venue', 'info.players.Pakistan', 'info.registry.people.Asmavia Iqbal', 'info.registry.people.Batool Fatima', 'info.registry.people.Bismah Maroof', 'info.registry.people.FC Leydon-Davis', 'info.registry.people.FL Mackay', 'info.registry.people.J Srinath', 'info.registry.people.Javeria Khan', 'info.registry.people.MJG Nielsen', 'info.registry.people.NJ Browne', 'info.registry.people.Nahida Khan', 'info.registry.people.Nain Abidi', 'info.registry.people.Nida Dar', 'info.registry.people.PR Reiffel', 'info.registry.people.Qanita Jalil', 'info.registry.people.REJ Martinesz', 'info.registry.people.RH Priest', 'info.registry.people.S Ravi', 'info.registry.people.SJ McGlashan', 'info.registry.people.Sadia Yousuf', 'info.registry.people.Sana Mir', 'info.registry.people.Sumaiya Siddiqi', 'info.players.England', 'info.players.South Africa', 'info.registry.people.A Bosch', 'info.registry.people.A Capsey', 'info.registry.people.A Khaka', 'info.registry.people.AE Jones', 'info.registry.people.CL Tryon', 'info.registry.people.D Tucker', 'info.registry.people.DN Wyatt', 'info.registry.people.FG Kemp', 'info.registry.people.IECM Wong', 'info.registry.people.KH Brunt', 'info.registry.people.L Goodall', 'info.registry.people.L Wolvaardt', 'info.registry.people.M Klaas', 'info.registry.people.M du Preez', 'info.registry.people.ME Bouchier', 'info.registry.people.N Mlaba', 'info.registry.people.NR Sciver', 'info.registry.people.Phil Whitticase', 'info.registry.people.RJ Bailey', 'info.registry.people.S Ecclestone', 'info.registry.people.S Glenn', 'info.registry.people.S Jafta', 'info.registry.people.SIR Dunkley', "info.registry.people.SJ O'Shaughnessy", 'info.registry.people.SM Bartlett', 'info.registry.people.T Brits', 'info.players.Botswana', 'info.players.Namibia', 'info.registry.people.A Mokgotlhe', 'info.registry.people.Adri van der Merwe', 'info.registry.people.B Gaanamong', 'info.registry.people.B Madimabe', 'info.registry.people.B Mpedi', 'info.registry.people.D Foerster', 'info.registry.people.E Simeon', 'info.registry.people.F Samanyika', 'info.registry.people.G Matome', 'info.registry.people.JA Diergaardt', 'info.registry.people.KA Green', 'info.registry.people.L Mophakedi', 'info.registry.people.M Ramafifi', 'info.registry.people.O Batisani', 'info.registry.people.Reehana Khan', 'info.registry.people.S Mosweu', 'info.registry.people.S Namusha', 'info.registry.people.SN Shihepo', 'info.registry.people.T Legaabile', 'info.registry.people.V Hamunyela', 'info.registry.people.W Mwatile', 'info.registry.people.Yasmeen Khan', 'info.players.Sierra Leone', 'info.registry.people.AM Kamara', 'info.registry.people.Adama Kamara', 'info.registry.people.Aminata Kamara', 'info.registry.people.F Bangur', 'info.registry.people.I Koroma', 'info.registry.people.J Kowa', 'info.registry.people.L Bull', 'info.registry.people.M King', 'info.registry.people.M Sankoh', 'info.registry.people.R Kassim', 'info.registry.people.Z Kamara', 'info.players.West Indies', 'info.registry.people.A Mohammed', 'info.registry.people.AA Alleyne', 'info.registry.people.B Cooper', 'info.registry.people.CA Henry', 'info.registry.people.CN Nation', 'info.registry.people.D van Niekerk', 'info.registry.people.DJS Dottin', 'info.registry.people.Danesh Ramdhanie', 'info.registry.people.HK Matthews', 'info.registry.people.JS Wilson', 'info.registry.people.Jonathan Blades', 'info.registry.people.K Ramharack', 'info.registry.people.Kycia A Knight', 'info.registry.people.Kyshona A Knight', 'info.registry.people.L Lee', 'info.registry.people.M Kapp', 'info.registry.people.Q Joseph', 'info.registry.people.Reon King', 'info.registry.people.S Luus', 'info.registry.people.T Chetty', 'info.registry.people.B Bezuidenhout', 'info.registry.people.CA Polosak', 'info.registry.people.JM Watkin', 'info.registry.people.LM Kasperek', 'info.registry.people.PJ Gillespie', 'info.registry.people.SAJ Craig', 'info.registry.people.SJ Nogajski', 'info.registry.people.SR Bernard', 'info.players.Bangladesh', 'info.players.Kenya', 'info.registry.people.E Wachira', 'info.registry.people.Fargana Hoque', 'info.registry.people.GS Lakshmi', 'info.registry.people.L Idambo', 'info.registry.people.M Ngoche', 'info.registry.people.M Ochieng', 'info.registry.people.Murshida Khatun', 'info.registry.people.Nahida Akter', 'info.registry.people.Nigar Sultana', 'info.registry.people.Q Abel', 'info.registry.people.R Achando', 'info.registry.people.Ritu Moni', 'info.registry.people.Rumana Ahmed', 'info.registry.people.S Juma', 'info.registry.people.S Mostary', 'info.registry.people.S Wetoto', 'info.registry.people.SW Kinyua', 'info.registry.people.Salma Khatun', 'info.registry.people.Sanjida Akter Meghla', 'info.registry.people.Shamima Sultana', 'info.registry.people.Shiju Sam', 'info.registry.people.Suraiya Azmin', 'info.registry.people.V Abuga', 'info.registry.people.V Kalidas', 'info.registry.people.V Ooko', 'info.registry.people.Vinod Babu', 'info.registry.people.A van der Merwe', 'info.registry.people.E Van Zyl', 'info.registry.people.F Odhiambo', 'info.registry.people.Habib Enesi', 'info.registry.people.I van Zyl', 'info.registry.people.Itangishaka Olivier', 'info.registry.people.J Otieno', 'info.registry.people.M Gorases', 'info.registry.people.M Idambo', 'info.registry.people.SA Wittmann', 'info.registry.people.Vicky Prajapati', 'info.registry.people.AJ Blackwell', 'info.registry.people.Aliya Riaz', 'info.registry.people.D Talalla', 'info.registry.people.EA Osborne', 'info.registry.people.GA Abood', 'info.registry.people.GC Joshua', 'info.registry.people.JL Hunter', 'info.registry.people.Marina Iqbal', 'info.registry.people.RM Farrell', 'info.registry.people.SJ Coyte', 'info.registry.people.Sania Khan', 'info.registry.people.Sidra Nawaz', 'info.registry.people.AN Davidson-Richards', 'info.registry.people.BF Smith', 'info.registry.people.D Hazell', 'info.registry.people.FC Wilson', 'info.registry.people.HAS Khalid', 'info.registry.people.HC Knight', 'info.registry.people.JL Gunn', 'info.registry.people.KL George', 'info.registry.people.KN Ananthapadmanabhan', 'info.registry.people.M Nayyar', 'info.registry.people.R Pandit', 'info.registry.people.TT Beaumont', 'info.registry.people.UV Gandhe', 'info.players.France', 'info.players.Germany', 'info.registry.people.A Bierwisch', 'info.registry.people.A Doddaballapur', 'info.registry.people.AM Healey', 'info.registry.people.Adnan Khan', 'info.registry.people.B Maes Loch', 'info.registry.people.C Breteche', 'info.registry.people.CM Gough', 'info.registry.people.DH Mclean', 'info.registry.people.DL Graham', 'info.registry.people.E Brelivet', 'info.registry.people.E Chance', 'info.registry.people.J King', 'info.registry.people.JE Ronalds', 'info.registry.people.K Vijayaraghavan', 'info.registry.people.LM Aramas', 'info.registry.people.M Cargouet', 'info.registry.people.M Jameson', 'info.registry.people.ME Violleau', 'info.registry.people.MS Beresford', 'info.registry.people.PA Wadenpohl', 'info.registry.people.PC McGeown', 'info.registry.people.S Sadarangani', 'info.registry.people.ST Frohnmayer', 'info.registry.people.T Rodriguez', 'info.registry.people.TE Britton', 'info.registry.people.ASS Fletcher', 'info.registry.people.Denavon Hayles', 'info.registry.people.JM Williams', 'info.registry.people.NY McLean', 'info.registry.people.P Vastrakar', 'info.registry.people.PA Gustard', 'info.registry.people.S Pandey', 'info.registry.people.SA Campbelle', 'info.registry.people.SACA King', 'info.registry.people.SC Selman', 'info.registry.people.Shafali Verma', 'info.registry.people.Zahid Bassarath', 'info.players.Ireland', 'info.registry.people.AA Baig', 'info.registry.people.Ayasha Rahman', 'info.registry.people.Bala Kailash', 'info.registry.people.CJ Metcalfe', 'info.registry.people.CMA Shillington', 'info.registry.people.CNIM Joyce', 'info.registry.people.EAJ Richardson', 'info.registry.people.Fahima Khatun', 'info.registry.people.GH Lewis', 'info.registry.people.IMHC Joyce', 'info.registry.people.Jahanara Alam', 'info.registry.people.K Gallagher', 'info.registry.people.KJ Garth', 'info.registry.people.Khadija Tul Kubra', 'info.registry.people.L Delany', 'info.registry.people.L Maritz',
                     'info.registry.people.MV Waldron', 'info.registry.people.PA Reynolds', 'info.registry.people.SM Kavanagh', 'info.registry.people.Sanjida Islam', 'info.players.Rwanda', 'info.registry.people.B Murekatete', 'info.registry.people.C Uwamahoro', 'info.registry.people.C Uwase', 'info.registry.people.EH Dusabemungu', 'info.registry.people.F Irakoze', 'info.registry.people.G Ishimwe', 'info.registry.people.H Ishimwe', 'info.registry.people.I Muhawenimana', 'info.registry.people.John Mayeku', 'info.registry.people.M Uwase', 'info.registry.people.M Vumiliya', 'info.registry.people.MD Bimenyimana', 'info.registry.people.O Keitsemang', 'info.registry.people.O Kgeresi', 'info.registry.people.S Uwera', 'info.registry.people.T Modise', 'info.registry.people.T Shadrack', 'info.registry.people.DC Boon', 'info.registry.people.HL Ferling', 'info.registry.people.HR Huddleston', 'info.registry.people.IJ Gould', 'info.registry.people.JE Cameron', 'info.registry.people.M Erasmus', 'info.players.Nigeria', 'info.registry.people.A Ikuzwe', 'info.registry.people.A Obulor', 'info.registry.people.B Etim', 'info.registry.people.DI Dusabemungu', 'info.registry.people.E Sandy', 'info.registry.people.F Eseigbe', 'info.registry.people.J Efosa', 'info.registry.people.Jackson Nzayisenga', 'info.registry.people.K Abdulquadri', 'info.registry.people.M Desmond', 'info.registry.people.O Asika', 'info.registry.people.O Omonkhobio', 'info.registry.people.R Samson', 'info.registry.people.S Ingabire', 'info.registry.people.S Sunday', 'info.registry.people.A van Schoor', 'info.registry.people.E Gare', 'info.registry.people.EU Kejarukua', 'info.registry.people.Hannes van Vuuren', 'info.registry.people.M Bosman', 'info.registry.people.M Short', 'info.registry.people.Pieter Groenewald', 'info.registry.people.V Thari Thari', 'info.players.Nepal', 'info.players.China', 'info.registry.people.A Bidari', 'info.registry.people.Apsari Begam', 'info.registry.people.B Rawal', 'info.registry.people.C Zhou', 'info.registry.people.DN Subedi', 'info.registry.people.F Song', 'info.registry.people.Han Lili', 'info.registry.people.Huang Zhuo', 'info.registry.people.I Barma', 'info.registry.people.K Kunwar', 'info.registry.people.K Shrestha', 'info.registry.people.Karuna Bhandari', 'info.registry.people.L Jie', 'info.registry.people.LI Haoye', 'info.registry.people.Nary Thapa', 'info.registry.people.Neeyamur Rashid', 'info.registry.people.RC Belbashi', 'info.registry.people.S Magar', 'info.registry.people.SR Magar', 'info.registry.people.Sharfuddoula', 'info.registry.people.Wang Meng', 'info.registry.people.Wu Juan', 'info.registry.people.Zhang Chan', 'info.registry.people.Zhang Mei', 'info.registry.people.Zhang Xiangxue', 'info.registry.people.A King', 'info.registry.people.CE Dean', 'info.registry.people.D Brown', 'info.registry.people.Eloise Sheridan', 'info.registry.people.FR Davies', 'info.registry.people.GM Harris', 'info.registry.people.TM McGrath', 'info.registry.people.A Shrubsole', 'info.registry.people.Ahsan Raza', 'info.registry.people.CM Brown', 'info.registry.people.Kim Cotton', 'info.registry.people.L Rusere', 'info.registry.people.L Winfield', 'info.registry.people.S Ismail', 'info.registry.people.A Hartley', 'info.registry.people.AG Wharf', 'info.registry.people.Aiman Anwer', 'info.registry.people.Anam Amin', 'info.registry.people.DJ Millns', 'info.registry.people.Iram Javed', 'info.registry.people.MJ Saggers', 'info.registry.people.Muneeba Ali', 'info.registry.people.NE Farrant', 'info.registry.people.Hein Heydenrych', 'info.registry.people.BC Broad', 'info.registry.people.Lauren Agenbag', 'info.registry.people.Panna Ghosh', 'info.registry.people.RM Ghosh', 'info.registry.people.RS Gayakwad', 'info.players.Sri Lanka', 'info.registry.people.AC Jayangani', 'info.registry.people.H Karunaratne', 'info.registry.people.H Madavi', 'info.registry.people.HASD Siriwardene', 'info.registry.people.HIS Mendis', 'info.registry.people.I Ranaweera', 'info.registry.people.JWHD Boteju', 'info.registry.people.LA Marsh', 'info.registry.people.LCN Smith', 'info.registry.people.MADD Surangika', 'info.registry.people.NND de Silva', 'info.registry.people.OU Ranasinghe', 'info.registry.people.RR Wimalasiri', 'info.registry.people.SIP Fernando', 'info.registry.people.U Thimashini', 'info.registry.people.WC Labrooy', 'info.registry.people.WN de Silva', 'info.registry.people.BYA Mendis', 'info.registry.people.EA Burns', 'info.registry.people.KADA Kanchana', 'info.registry.people.KDU Prabodhani', 'info.registry.people.MAA Sanjeewani', 'info.registry.people.SA Lightbody', 'info.registry.people.AC Brodin', 'info.registry.people.EC Bargna', 'info.registry.people.I Vrignaud', 'info.registry.people.SPY Baron', 'info.registry.people.SR McAnanama-Brereton', 'info.registry.people.V Stolle', 'info.registry.people.A Mehrotra', 'info.registry.people.BF Bowden', 'info.registry.people.CA Gurrey', 'info.registry.people.GA Stirrat', 'info.registry.people.GAV Baxter', 'info.registry.people.HM Rowe', 'info.registry.people.PS Punia', 'info.registry.people.GA Elwiss', 'info.registry.people.MA Gough', 'info.registry.people.Maham Tariq', 'info.registry.people.RT Robinson', 'info.registry.people.Sidra Ameen', 'info.registry.people.A Canning', 'info.registry.people.AN Kelly', 'info.registry.people.Aidan Seaver', 'info.registry.people.C Murray', 'info.registry.people.J Maguire', 'info.registry.people.Jonathan Kennedy', 'info.registry.people.L Paul', 'info.registry.people.M Hawthorne', 'info.registry.people.O Prendergast', 'info.registry.people.Philip Thompson', 'info.registry.people.R Stokell', 'info.registry.people.Rachel Delaney', 'info.registry.people.A Brindle', 'info.registry.people.CM Edwards', 'info.registry.people.GD Lloyd', 'info.registry.people.HL Colvin', 'info.registry.people.JB Nero', 'info.registry.people.MR Aguilleira', 'info.registry.people.P Willey', 'info.registry.people.SJ Taylor', 'info.registry.people.SR Taylor', 'info.registry.people.TD Smartt', 'info.registry.people.Diana Baig', 'info.registry.people.Ghaffar Kazmi', 'info.registry.people.Khalid Mahmood', 'info.registry.people.Muhammad Javed', 'info.registry.people.Syeda Aroob Shah', 'info.registry.people.Umaima Sohail', 'info.registry.people.Zaidan Taha', 'info.registry.people.GF Labrooy', 'info.registry.people.Iftikhar Ali', 'info.registry.people.M Daniels', 'info.registry.people.MM Letsoalo', 'info.registry.people.NA Moodley', 'info.registry.people.Rabiya Shah', 'info.registry.people.Y Fourie', 'info.registry.people.A Aitken', 'info.registry.people.A Lister', 'info.registry.people.EL Watson', 'info.registry.people.GWHM Perera', 'info.registry.people.HRA Rainey', 'info.registry.people.K Fraser', 'info.registry.people.R Slater', 'info.registry.people.RMVD Gunaratne', 'info.registry.people.S Nisansala', 'info.registry.people.WK Dilhari', 'info.registry.people.LAGL Kirby', 'info.registry.people.SS Connell', 'info.outcome.method', 'info.registry.people.Ayesha Naseem', 'info.registry.people.CO Wright', 'info.registry.people.Christopher Taylor', 'info.registry.people.Fatima Sana', 'info.registry.people.Javeria Rauf', 'info.registry.people.Nashra Sandhu', 'info.registry.people.Verdayne Smith', 'info.players.Bahrain', 'info.players.Saudi Arabia', 'info.registry.people.A Samildeen', 'info.registry.people.Abeer Maryam', 'info.registry.people.Amna Khan', 'info.registry.people.Azad KR', 'info.registry.people.C Sewsunker', 'info.registry.people.D Bhaskara', 'info.registry.people.Emaan Ejaz', 'info.registry.people.HMD Rasangika', 'info.registry.people.Hanoz Iqbal', 'info.registry.people.Mah Noor Amir', 'info.registry.people.Maira Khan', 'info.registry.people.N Krishnan', 'info.registry.people.P Shetty', 'info.registry.people.Prajna Jagdeesha', 'info.registry.people.R Hathadurage', 'info.registry.people.R Rodrigo', 'info.registry.people.Rida Syeda', 'info.registry.people.Ruba Rashid', 'info.registry.people.S Jayasinghe', 'info.registry.people.S Prakash', 'info.registry.people.S Sattar', 'info.registry.people.Saba Ali Syeda', 'info.registry.people.Simrah Mirza', 'info.registry.people.TI Gajanayake', 'info.registry.people.V Barboza', 'info.registry.people.Zoha Irfan', 'info.registry.people.BB Pradhan', 'info.registry.people.E Bisht', 'info.registry.people.J Goswami', 'info.registry.people.M Raj', 'info.registry.people.Sarika Prasad', 'info.registry.people.Shozab Raza', 'info.registry.people.AJ Pycroft', 'info.registry.people.C Shamshuddin', 'info.registry.people.RSA Palliyaguruge', 'info.registry.people.S Verma', 'info.registry.people.VR Vanitha', 'info.registry.people.BMSM Kumari', 'info.registry.people.CB Gaffaney', 'info.registry.people.KM Beams', 'info.registry.people.LE Kaushalya', 'info.registry.people.MDN Hansika', 'info.registry.people.PM Weerakkody', 'info.registry.people.AL Gillies', 'info.registry.people.AM Peterson', 'info.registry.people.Damian Morrow', 'info.registry.people.M Joshi', 'info.registry.people.AL Hill', 'info.registry.people.JM Fields', 'info.registry.people.LC Sthalekar', 'info.registry.people.LS Greenway', 'info.registry.people.A Deshmukh', 'info.registry.people.BS Fulmali', 'info.registry.people.GR Sadashiv Iyer', 'info.registry.people.H Deol', 'info.registry.people.KL Cross', 'info.registry.people.N Pandit', 'info.registry.people.V Narayan Kutty', 'info.registry.people.ID Blackwell', 'info.registry.people.MK Villiers', 'info.registry.people.PK Baldwin', 'info.registry.people.S Rana', 'info.registry.people.A Sharma', 'info.registry.people.Asad Rauf', 'info.registry.people.CR Seneviratna', 'info.registry.people.N Niranjana', 'info.registry.people.PG Raut', 'info.registry.people.R Malhotra', 'info.registry.people.RK Parwin', 'info.registry.people.S Naik', 'info.registry.people.SI Galagedara', 'info.registry.people.SK Dolawatte', 'info.registry.people.F Tunnicliffe', 'info.registry.people.Saarah Smith', 'info.registry.people.TS Sekhukhune', 'info.registry.people.Z Mali', 'info.registry.people.BCMS Mendis',
                     'info.registry.people.HML Madushani', 'info.registry.people.HMNC Danasinghe', 'info.registry.people.ID Gunawardene', 'info.registry.people.RD Kottahachchi', 'info.registry.people.SF Daley', 'info.registry.people.SL Munroe', 'info.registry.people.SS Weerakkody', 'info.players.Thailand', 'info.players.United Arab Emirates', 'info.registry.people.Akbar Ali', 'info.registry.people.C Sutthiruang', 'info.registry.people.Chaya Mughal', 'info.registry.people.ER Oza', 'info.registry.people.Humaira Tasneem', 'info.registry.people.I Seneviratne', 'info.registry.people.KKN Egodage', 'info.registry.people.N Boochatham', 'info.registry.people.N Chaiwai', 'info.registry.people.N Chantam', "info.registry.people.N D'souza", 'info.registry.people.N Koncharoenkai', 'info.registry.people.N Sharma', 'info.registry.people.O Kamchomphu', 'info.registry.people.R Padunglerd', 'info.registry.people.S Dharnidharka', 'info.registry.people.S Laomi', 'info.registry.people.S Saenya', 'info.registry.people.S Tippoch', 'info.registry.people.S Venkataraman', 'info.registry.people.Tabarak Dar', 'info.registry.people.UCKA Dona', 'info.registry.people.VK Jha', 'info.registry.people.W Liengprasert', 'info.registry.people.C Raack', 'info.registry.people.HKG Jansen', 'info.registry.people.L Little', 'info.registry.people.R Kemming', 'info.registry.people.Ryan Milne', 'info.registry.people.S Lateh', 'info.registry.people.U Raymond-Hoey', 'info.registry.people.A Das', 'info.registry.people.G Sultana', 'info.registry.people.KV Jain', 'info.registry.people.NJ Llong', 'info.registry.people.RK Illingworth', 'info.registry.people.RS Mahanama', 'info.registry.people.S Sharma', 'info.registry.people.SK Naidu', 'info.players.Uganda', 'info.registry.people.A Maasz', 'info.registry.people.C Aweko', 'info.registry.people.E Anyipo', 'info.registry.people.H Hugo', 'info.registry.people.J Mbabazi', 'info.registry.people.K Awino', 'info.registry.people.L Haccou', 'info.registry.people.Mohammed Jimia', 'info.registry.people.NK Bagenda', 'info.registry.people.P Malemikia', 'info.registry.people.PE Kulume', 'info.registry.people.R Musamali', 'info.registry.people.RE Nyangendo', 'info.registry.people.S Akiteng', 'info.registry.people.BG Frost', 'info.registry.people.EA Watkin', 'info.registry.people.EC Perry', 'info.registry.people.KE Broadmore', 'info.registry.people.LR Doolan', 'info.registry.people.PD Jones', 'info.registry.people.SE Rowe', 'info.registry.people.AJ Kenealy', 'info.registry.people.EJ Tice', 'info.registry.people.J Gray', "info.registry.people.LK O'Reilly", 'info.registry.people.LN McCarthy', 'info.registry.people.Lata Mondal', 'info.registry.people.MEMO Scott-Hayward', 'info.registry.people.Shaila Sharmin', 'info.registry.people.Sharmin Akhter', 'info.registry.people.Shohely Akhter', 'info.players.Zimbabwe', 'info.registry.people.AC Mushangwe', 'info.registry.people.CT Dhururu', 'info.registry.people.E Haynes', 'info.registry.people.J Nkomo', 'info.registry.people.JJ Luck', 'info.registry.people.K Ndlovu', 'info.registry.people.L Phiri', 'info.registry.people.M Mavunga', 'info.registry.people.M Mupachikwa', 'info.registry.people.N Gwanzura', 'info.registry.people.P Marange', 'info.registry.people.P Mujaji', 'info.registry.people.S Kakai', 'info.registry.people.SM Mayers', 'info.registry.people.Shakirah Sadick', 'info.registry.people.A Hunter', 'info.registry.people.AJ Neill', 'info.registry.people.Jareth McCready', 'info.registry.people.N de Klerk', 'info.registry.people.Nitin Menon', 'info.players.Malaysia', 'info.players.Hong Kong', 'info.registry.people.A Natarajan', 'info.registry.people.Ainna Hamizah Hashim', 'info.registry.people.Aisya Eleesa', 'info.registry.people.Bella Poon', 'info.registry.people.Chan Ka Man', 'info.registry.people.EK Hubbard', 'info.registry.people.Edwin Seah', 'info.registry.people.Hiu Ying Cheung', 'info.registry.people.Iqra Sahar', 'info.registry.people.J Intan', 'info.registry.people.KY Chan', 'info.registry.people.M Bibi', 'info.registry.people.M Hill', 'info.registry.people.Mas Elysa', 'info.registry.people.NT Miles', 'info.registry.people.Nik Nur Atiela', 'info.registry.people.Nur Arianna Natsya', 'info.registry.people.Nur Dania Syuhada', 'info.registry.people.Sasha Azmi', 'info.registry.people.Shanzeen Shahzad', 'info.registry.people.Siow Tzin Yee', 'info.registry.people.WA Duraisingam', 'info.registry.people.Wan Julia', 'info.registry.people.Y Daswani', 'info.registry.people.Ahmed Shah Pakteen', 'info.registry.people.S Saengsakaorat', 'info.registry.people.I Nandakumar', 'info.registry.people.Kaushik Vyas', 'info.registry.people.Khazaima', 'info.registry.people.Khushi Sharma', 'info.registry.people.L Keny', 'info.registry.people.M Gaur', 'info.registry.people.Najwa Akram', 'info.registry.people.R Mohan', 'info.registry.people.Rinitha Rajith', 'info.registry.people.S Gokhale', 'info.registry.people.S Kotte', 'info.registry.people.Theertha Satish', 'info.registry.people.Vaishnave Mahesh', 'info.registry.people.Zaman Quoraishi', 'info.registry.people.GH Black', 'info.registry.people.J McGeehan', 'info.registry.people.L Fourie', 'info.registry.people.M Shehani', 'info.registry.people.Renuka Singh', 'info.registry.people.S Meghana', 'info.registry.people.SD Bahadur', 'info.registry.people.Susantha Dissanayake', 'info.registry.people.YH Bhatia', 'info.players.Papua New Guinea', 'info.registry.people.B Tau', 'info.registry.people.H Hotchandani', 'info.registry.people.J Cleetus', 'info.registry.people.K Arua', 'info.registry.people.K John', 'info.registry.people.M Tom', 'info.registry.people.N Vare', 'info.registry.people.Nisha Ali', 'info.registry.people.P Siaka', 'info.registry.people.R Oa', 'info.registry.people.Roopa Nagraj', 'info.registry.people.S Jimmy', 'info.registry.people.T Ruma', 'info.registry.people.V Araa', 'info.registry.people.V Frank', 'info.players.Indonesia', 'info.registry.people.E Eduard', 'info.registry.people.H Buruka', 'info.registry.people.H Nou', 'info.registry.people.K Winda Prastini', 'info.registry.people.N Sitompul', 'info.registry.people.NKF Rada Rani', 'info.registry.people.NM Ambo', 'info.registry.people.NMP Suwandewi', 'info.registry.people.NPAN Sakarini', 'info.registry.people.P Haryanti', 'info.registry.people.Suresh Subramanian', 'info.registry.people.T Hanum', 'info.registry.people.T Wigradianti', 'info.registry.people.Y Anggraeni', 'info.registry.people.Yuliana', 'info.registry.people.ZK Shem', 'info.players.Mozambique', 'info.registry.people.A Cossa', 'info.registry.people.A Uwimbabazi', 'info.registry.people.AL Mangue', 'info.registry.people.C Magaia', 'info.registry.people.C Murrombe', 'info.registry.people.HR Ponja', 'info.registry.people.I Chuma', 'info.registry.people.IO Oyieko', 'info.registry.people.O Matsolo', 'info.registry.people.OC Moiane', 'info.registry.people.P Cuinica', 'info.registry.people.R Haiong', 'info.registry.people.S Bhargava', 'info.registry.people.TJE Chiracheque', 'info.players.Austria', 'info.registry.people.A Meyenborg', 'info.registry.people.A Nookala', 'info.registry.people.AM Zepeda', 'info.registry.people.Arsalan Arif', 'info.registry.people.Busra Uca', 'info.registry.people.Dharminder Pal Rauhia', 'info.registry.people.H Bhullar', 'info.registry.people.H Dhaliwal', 'info.registry.people.JA Stiglitz', 'info.registry.people.K Qureshi', 'info.registry.people.L Skatulla', 'info.registry.people.P Sabu', 'info.registry.people.R Avdylaj', 'info.registry.people.Rajinder Kumar', 'info.registry.people.S Kailath', 'info.registry.people.SB Chamundaiah', 'info.registry.people.V Avdylaj', 'info.registry.people.JE Titmuss', 'info.registry.people.JM Davies', 'info.registry.people.M Wai Siu', 'info.registry.people.MBA Lamplough', 'info.registry.people.Ruchitha Venkatesh', 'info.registry.people.YS To', 'info.registry.people.Zheng Lili', 'info.registry.people.M Yousaf', 'info.registry.people.Ryu Roni', 'info.registry.people.Shahid Gill', 'info.registry.people.Sun Meng Yao', 'info.registry.people.Asif Yaqoob', 'info.registry.people.Kainat Imtiaz', 'info.registry.people.Mohammed Anees', 'info.registry.people.Sadia Iqbal', 'info.registry.people.Tariq Rasheed', 'info.registry.people.D Njoroge', 'info.registry.people.M Mwangi', 'info.registry.people.Tharika Sewwandi', 'info.registry.people.PJ Hartley', 'info.registry.people.SL Quintyne', 'info.registry.people.MR Meshram', 'info.registry.people.HAM Samuddika', 'info.registry.people.PRCS Kumarihami', 'info.registry.people.RS Vandort', 'info.registry.people.JH Evans', 'info.registry.people.R Ntozakhe', 'info.players.Brazil', 'info.registry.people.D Staddon', 'info.registry.people.E de Souza', 'info.registry.people.J Nyirankundineza', 'info.registry.people.L Agatha', 'info.registry.people.L Moises', 'info.registry.people.LV Boas', 'info.registry.people.M Artur', 'info.registry.people.M Ribeiro', 'info.registry.people.MLG Silva', 'info.registry.people.NC Monteiro', 'info.registry.people.RD de Sousa', 'info.registry.people.RMAM Avery', 'info.registry.people.TJ Onikoyi', 'info.registry.people.LB Gcuma', 'info.registry.people.PJ Vosloo', 'info.registry.people.S Wadvalla', 'info.registry.people.Siphelele Gasa', 'info.registry.people.Stephen Harris', 'info.players.United States of America', 'info.registry.people.AG Rao', 'info.registry.people.C Beckford', 'info.registry.people.EH Rendler', 'info.registry.people.L Ramjit', 'info.registry.people.NT Gruny', 'info.registry.people.OT Wallerson', 'info.registry.people.S Bhaskar', 'info.registry.people.S Farooq', 'info.registry.people.S Ramautar', 'info.registry.people.S Sriharsha', 'info.registry.people.SK Chandhrasekar', 'info.registry.people.F Parkinson', 'info.registry.people.AK Peters', 'info.registry.people.D Venter', 'info.registry.people.DJ Walker', 'info.registry.people.NC Dodd', 'info.registry.people.R Boyce', 'info.registry.people.D Ireland', 'info.registry.people.L Cheatle', 'info.registry.people.Aleem Dar', 'info.registry.people.HDPK Dharmasena', 'info.registry.people.RS Madugalle', 
                     'info.registry.people.C Black', 'info.registry.people.JM Kerr', 'info.registry.people.JM Dibble', 'info.registry.people.RL Grundy', 'info.registry.people.SJ Davis', 'info.registry.people.I Toua', 'info.registry.people.R Black', 'info.registry.people.Adriaan van den Dries', 'info.registry.people.M Marchello', 'info.registry.people.Rizwan Akram', 'info.registry.people.CS Mugeri', 'info.registry.people.F Chipare', 'info.registry.people.M Musonda', 'info.registry.people.M Mwatile', 'info.registry.people.N Sibanda', 'info.players.Eswatini', 'info.registry.people.A Ndiraya', 'info.registry.people.D Dlamini', 'info.registry.people.E Mbofana', 'info.registry.people.GH Pienaar', 'info.registry.people.K Maseko', 'info.registry.people.L Tshuma', 'info.registry.people.M Dlamini', 'info.registry.people.N Gwebu', 'info.registry.people.N Khumalo', 'info.registry.people.N Mabila', 'info.registry.people.Ntombizodwa Mkhatshwa', 'info.registry.people.Ntombizonke MKhatshwa', "info.registry.people.R D'Mello", 'info.registry.people.S Mabuza', 'info.registry.people.T Granger', 'info.registry.people.T Malinga', 'info.registry.people.W Ginindza', 'info.registry.people.D Busingye', 'info.registry.people.F Najjumba', 'info.registry.people.I Nakisuuyi', 'info.registry.people.O Chirombe', 'info.registry.people.R Ntono', 'info.registry.people.S Nampiina', 'info.registry.people.S Walaza', 'info.registry.people.S MacMahon', 'info.registry.people.BM Halliday', 'info.registry.people.BV Taylor', 'info.registry.people.EL Lamb', 'info.registry.people.TMM Newton', 'info.registry.people.Wayne Noon', 'info.registry.people.A Wellington', 'info.registry.people.JD Ward', 'info.registry.people.M Strano', 'info.registry.people.AH Thomson', 'info.registry.people.EN Lynch', 'info.registry.people.F Overdijk', 'info.registry.people.I van der Woning', 'info.registry.people.J van Vliet', 'info.registry.people.M Hancock', 'info.registry.people.M Prabhudesa', 'info.registry.people.N Bathi', 'info.registry.people.M Sheriff', 'info.registry.people.N Squire', 'info.registry.people.PM Musoke', 'info.registry.people.A Kohli', 'info.registry.people.C Pfalzner-Gibbon', 'info.registry.people.Praveen Kumar Swamidas', 'info.registry.people.T Kazanci', 'info.registry.people.CC Dalton', 'info.registry.people.EM Bermingham', 'info.registry.people.Navdeep Singh', 'info.registry.people.VA Kulkarni', 'info.registry.people.HHC Gunaratne', 'info.registry.people.SRH Curtis', 'info.registry.people.A Igbobie', 'info.registry.people.S Agazuma', 'info.registry.people.Ranjeev Sharma', 'info.players.Kuwait', 'info.registry.people.A Bose', 'info.registry.people.Amna Tariq', 'info.registry.people.B Shanti', 'info.registry.people.Khadija Khalil', 'info.registry.people.Maria Jasvi', 'info.registry.people.Mariamma Hyder', 'info.registry.people.Maryam Omar', 'info.registry.people.Maryyam Ashraf', 'info.registry.people.Priyada Murali', 'info.registry.people.SL Gomez', 'info.registry.people.V Karthikeyan', 'info.registry.people.Zeefa Jilani', 'info.registry.people.M Burns', 'info.registry.people.S Gajnabi', 'info.registry.people.SS Grimmond', 'info.registry.people.CC van Slobbe', 'info.registry.people.EE Corder', 'info.registry.people.MEC de Fouw', 'info.registry.people.Mariska Kornet', 'info.players.Qatar', 'info.registry.people.A Mare', 'info.registry.people.Aleena Khan', 'info.registry.people.Aysha', 'info.registry.people.D Bhatta', 'info.registry.people.H Agarwal', 'info.registry.people.J Pandey', 'info.registry.people.KE Pounsett', 'info.registry.people.Khadija Imtiaz', 'info.registry.people.R Shah', 'info.registry.people.Rizpha Bano', 'info.registry.people.S Dhadwal', 'info.registry.people.SA Panayan', 'info.registry.people.SC Kumari', 'info.registry.people.SK Rana', 'info.registry.people.Sabnam Rai', 'info.registry.people.Sangita Rai', 'info.registry.people.LK Ebsary', 'info.players.Bhutan', 'info.registry.people.A Gurung', 'info.registry.people.A Karmacharya', 'info.registry.people.D Wangmo', 'info.registry.people.L Poobalan', 'info.registry.people.MM Chaudhary', 'info.registry.people.N Choden', 'info.registry.people.N Sivan', 'info.registry.people.P Seldon', 'info.registry.people.Ramesh Menon', 'info.registry.people.S Choden', 'info.registry.people.Sangay Wangmo', 'info.registry.people.Sonam', 'info.registry.people.T Cheki', 'info.registry.people.T Lhaden', 'info.registry.people.T Zangmo', 'info.registry.people.Y Choden', 'info.registry.people.Mahirah Izzati Ismail', 'info.registry.people.Noor Hayati Zakaria', "info.registry.people.VS D'Souza", 'info.registry.people.Wan Nor Zulaika', 'info.registry.people.Yusrina Yaakop', 'info.registry.people.AK Chaudhary', 'info.registry.people.CK Nandan', 'info.registry.people.K Cross', 'info.registry.people.N Janani', 'info.registry.people.G Kodali', 'info.registry.people.AK Wilds', 'info.registry.people.DB Mealey', 'info.registry.people.MP Enright', 'info.registry.people.Adhip Pradhan', 'info.registry.people.Anjali Chand', 'info.registry.people.Basu Karn', 'info.registry.people.Kamalesh Thakur', 'info.registry.people.Rabeya Khan', 'info.registry.people.S Khadka', 'info.registry.people.Satyajit Sarkar', 'info.registry.people.Chirra Ravikanthreddy', 'info.registry.people.J Madanagopal', 'info.registry.people.YC Barde', 'info.registry.people.K Dema', 'info.registry.people.K Joshi', 'info.registry.people.K Samten', 'info.registry.people.Rahul Asher', 'info.registry.people.S Paldon', 'info.registry.people.Akhtar Ahmad', 'info.registry.people.Masudur Rahman', 'info.registry.people.AP Ward', 'info.players.Tanzania', 'info.registry.people.A Louw', 'info.registry.people.A Mazvishaya', 'info.registry.people.FO Kibasu', 'info.registry.people.GL Mushi', 'info.registry.people.HM Omary', 'info.registry.people.Justine Muzungu', 'info.registry.people.M Pascal', 'info.registry.people.NJ Pius', 'info.registry.people.NN Saidi', 'info.registry.people.NO Tindo', 'info.registry.people.PZ Kamunya', 'info.registry.people.SH Mohamedi', 'info.registry.people.TS Omary', 'info.registry.people.Zinaida Jeremiah', 'info.registry.people.Ayesha Zafar', 'info.registry.people.N Shangase', 'info.registry.people.SA Fritz', 'info.registry.people.B Ramani', 'info.registry.people.Iqbal Sikander', 'info.registry.people.Lily Rani Biswas', 'info.registry.people.Liu Jingming', 'info.registry.people.Nuzhat Tasnia', 'info.registry.people.SV Sarda', 'info.registry.people.Tazia Akhter', 'info.registry.people.WGAKK Kulasuriya', 'info.registry.people.L Klokgieters', 'info.registry.people.D Devnarain', 'info.registry.people.SD Fry', 'info.registry.people.GR Menes', 'info.registry.people.Rida Zainab', 'info.registry.people.T Yangchen', 'info.registry.people.Y Wangmo', 'info.registry.people.AJ Barrow', 'info.registry.people.Aminul Islam', 'info.registry.people.Mariam Hasan', 'info.registry.people.S Jianxin', 'info.registry.people.RJ Ratnayake', 'info.registry.people.JJ Crowe', 'info.registry.people.JM Dempsey', 'info.registry.people.PJ Pasco', 'info.registry.people.NGC Cowley', 'info.registry.people.G Dempsey', 'info.registry.people.HWA Landheer', 'info.registry.people.P Jain', 'info.registry.people.AL Kerrison', 'info.players.Oman', 'info.registry.people.A Dcosta', 'info.registry.people.Alifiya Sayed', 'info.registry.people.B Shetty', 'info.registry.people.Fiza', 'info.registry.people.N Jagadish', 'info.registry.people.NM Anil', 'info.registry.people.PE Mendonca', 'info.registry.people.Rithika Rajith', 'info.registry.people.S Channa', 'info.registry.people.SV Shetty', 'info.registry.people.Sameera Khan', 'info.registry.people.V Jesrani', 'info.players.Lesotho', 'info.registry.people.B Lekau', 'info.registry.people.L Khotso', 'info.registry.people.M Moalosi', 'info.registry.people.M Mohasane', 'info.registry.people.M Tsarsi', 'info.registry.people.P Pheko', 'info.registry.people.R Khasana', 'info.registry.people.T Khabo', 'info.registry.people.T Kobeli', 'info.registry.people.T Koloi', 'info.registry.people.T Ramabitsa', 'info.registry.people.AG Hurst', 'info.registry.people.BL Morgan', 'info.registry.people.BR Doctrove', 'info.registry.people.CMG Atkins', 'info.registry.people.EAR de Silva', 'info.registry.people.KE Pike', 'info.registry.people.KL Rolton', 'info.registry.people.LJ Poulton', 'info.registry.people.NJ Shaw', 'info.registry.people.S Nitschke', 'info.registry.people.SC Taylor', 'info.registry.people.SJ Andrews', 'info.registry.people.Anjum Chopra', 'info.registry.people.AL Watkins', 'info.registry.people.KL Pulford', 'info.registry.people.MR Benson', 'info.registry.people.P Roy', 'info.registry.people.R Dhar', 'info.registry.people.SEA Ruck', 'info.registry.people.SJ Tsukigawa', 'info.registry.people.S Lackay', 'info.registry.people.AT Holdstock', 'info.registry.people.BP Jele', 'info.registry.people.Rameen Shamim', 'info.registry.people.CM Scott', 'info.registry.people.Chen Yue', 'info.registry.people.C Phiri', 'info.registry.people.ET Dube', 'info.registry.people.F Mutizwa', 'info.registry.people.I Chabi', 'info.registry.people.T Putthawong', 'info.registry.people.RS Quyn', 'info.registry.people.Samad Akbar', 'info.registry.people.Sanchin Singh', 'info.registry.people.Shahreeennawab', 'info.registry.people.T Kale', 'info.registry.people.BC Treloar', 'info.registry.people.A le Breton', 'info.registry.people.D Govindjee', 'info.registry.people.R Ellis', 'info.registry.people.RN Birkenstock', 'info.registry.people.S Loubser', 'info.registry.people.SM Benade', 'info.registry.people.Y van der Westhuizen', 'info.registry.people.M Mehta', 'info.registry.people.Soniya Dabir', 'info.registry.people.Nasir Ali', 'info.registry.people.Natalia Pervaiz', 'info.registry.people.Zameer Haider', 'info.registry.people.SM Dhanusri', 'info.registry.people.D Mukarurangwa', 'info.registry.people.M Imimole', 'info.registry.people.C Anayo', 'info.registry.people.E Iloku', 'info.registry.people.G Obukor', 'info.registry.people.JM Apio', 'info.registry.people.M Anyigo', 'info.registry.people.P Alako', 
                     'info.registry.people.V Iriho', 'info.players.Barbados', 'info.registry.people.A Scantlebury', 'info.registry.people.KO Elliott', 'info.registry.people.SJ Bruce', 'info.registry.people.Shivani Mishra', 'info.registry.people.T Holder', 'info.registry.people.RE Hayward', 'info.registry.people.Christina Baret', 'info.registry.people.Nur Nadihirah', 'info.registry.people.Zumika Azmi', 'info.registry.people.PN Udawatta', 'info.registry.people.RA Kottahachchi', 'info.players.Japan', 'info.registry.people.A Kanada', 'info.registry.people.A Kitayama', 'info.registry.people.Erika Oda', 'info.registry.people.IA Thomson', 'info.registry.people.K Nanno', 'info.registry.people.K Taniguchi', 'info.registry.people.M Kanno', 'info.registry.people.M Shiraishi', 'info.registry.people.M Yanagida', 'info.registry.people.N Tokizawa', 'info.registry.people.R Endo', 'info.registry.people.S Miyaji', 'info.registry.people.S Mtae', 'info.registry.people.Roma Thapa', 'info.registry.people.MA Swedy', 'info.registry.people.MH Ushanga', 'info.registry.people.MI Shakim', 'info.registry.people.SF Jerome', 'info.registry.people.S Meyenborg', 'info.registry.people.A Sutherland', 'info.registry.people.Andrew Crozier', 'info.players.Maldives', 'info.registry.people.Aima Aishath', 'info.registry.people.Eashal Ibrahim', 'info.registry.people.Hafsaa Abdhulla', 'info.registry.people.Hamza Niyaz', 'info.registry.people.Hiralal Raut', 'info.registry.people.Kinaanath Ismail', 'info.registry.people.Latsha Haleemath', 'info.registry.people.Maaha Naseer', 'info.registry.people.Manjul Bhattarai', 'info.registry.people.Manmohan Lamsal', 'info.registry.people.Manohar Adhikari', 'info.registry.people.S Khatiwada', 'info.registry.people.Sajaa Fathimath', 'info.registry.people.Shamma Ali', 'info.registry.people.Sumayya Abdul', 'info.registry.people.Zoona Mariyam', 'info.registry.people.Madeeha Zuberi', 'info.registry.people.Sabreen Zaki', 'info.registry.people.Iqra Ishaq', 'info.registry.people.NA Mallender', 'info.registry.people.NGB Cook', 'info.registry.people.C Namugenyi', 'info.registry.people.G Candiru', 'info.registry.people.L Grant', 'info.registry.people.S Kemigisha', 'info.registry.people.WK Lai', 'info.registry.people.NM Cherriath', 'info.registry.people.V Subha', 'info.registry.people.JD Cloete', 'info.registry.people.Afzalkhan Pathan', 'info.registry.people.Javed Hina', 'info.registry.people.Javed Hira', 'info.registry.people.S Nair', 'info.registry.people.Samir Parker', 'info.registry.people.Sani E Zehra', 'info.registry.people.Y Verma', 'info.registry.people.Aisha Rahman', 'info.players.Vanuatu', 'info.players.Samoa', 'info.registry.people.A Chilia', 'info.registry.people.A Kapa', 'info.registry.people.FLV Pula', 'info.registry.people.JC Sokomanu', 'info.registry.people.KML Nonu', 'info.registry.people.L Tastuki', 'info.registry.people.LA Bourne', 'info.registry.people.LO Telea', 'info.registry.people.LR Aoina', 'info.registry.people.LS Mulivai', 'info.registry.people.M Mete', 'info.registry.people.M Tarimiala', 'info.registry.people.MI Tato', 'info.registry.people.MV Fare', 'info.registry.people.N Navaika', 'info.registry.people.R Andrew', "info.registry.people.RSM Lili'i", 'info.registry.people.S Solman', 'info.registry.people.SR Aoina', 'info.registry.people.T Iosefo', 'info.registry.people.T Lafai', 'info.registry.people.V Langiatu', 'info.registry.people.V Tari', 'info.registry.people.LE Hannibal', 'info.registry.people.WAA Wasantha', 'info.registry.people.A Salomao', 'info.registry.people.E Moiane', 'info.registry.people.F Guirrugo', 'info.registry.people.M Matine', 'info.registry.people.O Mondlane', 'info.registry.people.P Modimo', 'info.players.Malawi', 'info.registry.people.B Ndipo', 'info.registry.people.D Dzimau', 'info.registry.people.D Ndipo', 'info.registry.people.M Dailesi', 'info.registry.people.M Mabvuka', 'info.registry.people.S Dzimau', 'info.registry.people.S Hussein', 'info.registry.people.T Katunga', 'info.registry.people.T Luka', 'info.registry.people.T Tereza', 'info.registry.people.V Phiri', 'info.players.Canada', 'info.registry.people.A Kolan', 'info.registry.people.A Perera', 'info.registry.people.D Saxena', 'info.registry.people.GC Bhogle', 'info.registry.people.Hala Azmat', 'info.registry.people.Hiba Shamshad', 'info.registry.people.IM Vaghela', 'info.registry.people.KN Mirchandani', 'info.registry.people.M Chaudhary', 'info.registry.people.M Gill', 'info.registry.people.M Khokhar', 'info.registry.people.Mahrukh Imtiaz', 'info.registry.people.N Duguid', 'info.registry.people.S Vig', 'info.registry.people.S Zafar', 'info.registry.people.SN Bandekar', 'info.registry.people.SR Thadani', 'info.registry.people.Saniyah Zia', 'info.registry.people.TG Norris', 'info.registry.people.U Iftikhar', 'info.registry.people.BM White', 'info.registry.people.B Freeman', 'info.registry.people.E Waithaka', 'info.registry.people.Eric Hirwa', 'info.registry.people.J Kgang', 'info.registry.people.T Motlhabaphuti', 'info.registry.people.AS Qwele', 'info.registry.people.Gaston Niyibizi', 'info.registry.people.LM Babirye', 'info.registry.people.T Shabani', 'info.registry.people.CM Colleran', 'info.registry.people.M Block', 'info.registry.people.RA Dykes', 'info.registry.people.ELC Flanagan', 'info.registry.people.K McKenna', 'info.registry.people.Kamal Merchant', 'info.registry.people.Mohammad Nasim', 'info.registry.people.N Mutasa', 'info.registry.people.Patric Makumbi', 'info.registry.people.IS Mananelage', 'info.registry.people.VR Angara', 'info.registry.people.DM Braat', 'info.registry.people.RJ Tucker', 'info.registry.people.BL Aldridge', 'info.registry.people.DG Paterson', 'info.registry.people.EJ Carson', 'info.registry.people.FC Jonas', 'info.registry.people.IC Gaze', 'info.registry.people.VG Rathi', 'info.registry.people.C Brits', 'info.registry.people.E Theunissen', 'info.registry.people.LS Reifer', 'info.registry.people.PJ Nero', 'info.registry.people.TS Cordes', 'info.registry.people.LM Massawe', 'info.registry.people.M May', 'info.registry.people.N Magagula', 'info.players.Singapore', 'info.registry.people.Ada Bhasin', 'info.registry.people.CH Abeyratne', 'info.registry.people.GK Diviya', 'info.registry.people.I Shukla', 'info.registry.people.JS Pooranakaran', 'info.registry.people.KSVP Venu Madhav', 'info.registry.people.PSR Gurusinghe', 'info.registry.people.R Selvaratnam', 'info.registry.people.RR Seth', 'info.registry.people.Ravi Putcha', 'info.registry.people.Riyaa Bhasin', 'info.registry.people.Shafina Mahesh', 'info.registry.people.Vinu Kumar', 'info.registry.people.Zay Hua Tan', 'info.registry.people.L Udeh', 'info.registry.people.R Abdulrasak', 'info.registry.people.S Kolcharam', 'info.registry.people.W Hornero-Garcia', 'info.registry.people.Sneh Rana', 'info.registry.people.FEM Van Arkel', 'info.registry.people.H Little', 'info.registry.people.M Pethiyagoda', 'info.registry.people.MGMCP Gunawardene', 'info.registry.people.SPD Jayamahamudali', 'info.registry.people.Dharmalngam Suresh', 'info.registry.people.Foyes Ahmed', 'info.registry.people.H Dhavina', 'info.registry.people.NL Jacinta Si Ping', 'info.registry.people.Nur Alliah Asyqin', 'info.registry.people.R Butler', 'info.registry.people.SK Sonpethkar', 'info.registry.people.Shafia Hassan', 'info.registry.people.Smruthi Radhakrishnan', 'info.registry.people.Vathana Sreemurugavel', 'info.registry.people.Hung Ying Ho', 'info.registry.people.T Chabila', 'info.registry.people.C Mokibelo', 'info.registry.people.IN Ramage', 'info.registry.people.Farooq Ali Khan', 'info.registry.people.Naila Nazir', 'info.registry.people.Rashid Riaz', 'info.registry.people.VK Sharma', 'info.registry.people.MG Shankar', 'info.registry.people.S Guambe', 'info.registry.people.CR Smith', 'info.registry.people.DP David', 'info.registry.people.SJ Elliott', 'info.registry.people.M Ndhambi', 'info.registry.people.B Nwobodo', 'info.registry.people.F Fyneface', 'info.registry.people.OS Oyronke', 'info.registry.people.T Abdulquadri', 'info.registry.people.Dechen Zangmo', 'info.registry.people.G Fernando', 'info.registry.people.I Suhun', 'info.registry.people.A Barnes', 'info.registry.people.A Paleker', 'info.registry.people.DJ Smith', 'info.registry.people.K Oala', 'info.registry.people.Poorvaja Jagdeesha', 'info.registry.people.MJD Bodenham', 'info.registry.people.Hudaa Mohamedi', 'info.registry.people.M Kagoya', 'info.registry.people.W Kevin', 'info.registry.people.HR Giri', 'info.registry.people.Sanjay Gurung', 'info.registry.people.Damini Ramesh', 'info.registry.people.V Pasupathy', 'info.registry.people.RA Lewis', 'info.registry.people.Nurilyaa Natasya', 'info.registry.people.LK Bennett', 'info.players.Jersey', 'info.players.Guernsey', 'info.registry.people.A Merritt', 'info.registry.people.C Jennings', 'info.registry.people.C Miles', 'info.registry.people.C Milner', 'info.registry.people.CM Greechan', 'info.registry.people.E Duffy', 'info.registry.people.E Gouge', 'info.registry.people.Emily Merrien', 'info.registry.people.F Bulpitt', 'info.registry.people.F Copley', 'info.registry.people.G Wetherall', 'info.registry.people.H Eulenkamp', 'info.registry.people.J Savage', 'info.registry.people.L Greig', 'info.registry.people.M Le Ray', 'info.registry.people.M Maguire', 'info.registry.people.M Robinson', 'info.registry.people.O Morgan', 'info.registry.people.PJ Stahelin', 'info.registry.people.R Hubbard', 'info.registry.people.RM Hill', 'info.registry.people.T Smith', 'info.registry.people.NR Johnstone', 'info.registry.people.Jannatul Ferdus', 'info.registry.people.KD Jayawant', 'info.registry.people.M Zwilling', 'info.registry.people.Ruud Kaulingfreks', 'info.registry.people.AK Rana', 'info.registry.people.Preeti Bose', 'info.registry.people.JW Lloyds', 'info.registry.people.PR Pollard', 'info.registry.people.N Ila', 'info.registry.people.Abeera Waris', 'info.registry.people.Prassanna Haran', 'info.registry.people.Riyaz Kurupkar', 'info.registry.people.Tuba Hassan', 'info.registry.people.P Mazuze', 
                     'info.registry.people.G McCrea', 'info.registry.people.S Forbes', 'info.registry.people.Jamil Zaidi', 'info.registry.people.EJCLRC Rainford-Brent', 'info.registry.people.IT Guha', 'info.registry.people.JW Holder', 'info.registry.people.SA Garratt', 'info.registry.people.Ahmed Shahab', 'info.registry.people.Lui Els', 'info.registry.people.R Searle', 'info.registry.people.KL Gordon', 'info.registry.people.S Nunna', 'info.registry.people.Aasif Iqbal', 'info.registry.people.H Lui', 'info.registry.people.H Sin Yee', 'info.registry.people.Jeetendra Gupte', 'info.registry.people.Raziq Khan', 'info.registry.people.AR Shetty', 'info.registry.people.Ajith Dcosta', 'info.registry.people.AA Deshpande', 'info.registry.people.N Tanwar', 'info.registry.people.SN Pradhan', 'info.registry.people.TE Jesty', 'info.registry.people.AL Tiwari', 'info.registry.people.B Phelenyane', 'info.players.Mali', 'info.registry.people.A Kone', 'info.registry.people.A Sangare', 'info.registry.people.B Coulibaly', 'info.registry.people.M Coulibaly', 'info.registry.people.M Samake', 'info.registry.people.N Traore', 'info.registry.people.O Sow', 'info.registry.people.R Cisse', 'info.registry.people.S Kagnassy', 'info.registry.people.T Konate', 'info.registry.people.Y Sangare', 'info.registry.people.HJ Darlington', 'info.registry.people.Shameem Abdul Basheer', 'info.registry.people.Mahnoor Mahmood', 'info.registry.people.Faisal Afridi', 'info.registry.people.DH Sharma', 'info.registry.people.Pramesh Parab', 'info.registry.people.Roshni Ramesh', 'info.registry.people.Samantha Singham', 'info.registry.people.Sathish Balasubramaniam', 'info.registry.people.T Wang Ling', 'info.registry.people.N Shivsankar', 'info.registry.people.Y Potgieter', 'info.registry.people.Afida Afthab', 'info.registry.people.SA Sathiya', 'info.registry.people.P Nakitende', 'info.registry.people.I Alumo', 'info.registry.people.A Steyn', 'info.registry.people.RMPJ Rambukwella', 'info.registry.people.CS Nascimento', 'info.registry.people.K Ogola', 'info.registry.people.L Cardoso', 'info.registry.people.CS Fraser', 'info.registry.people.Meghna Singh', 'info.registry.people.B Frank', 'info.registry.people.D Igihozo', 'info.players.Fiji', 'info.registry.people.A Kano', 'info.registry.people.A Tagilala', 'info.registry.people.Eri Iko', 'info.registry.people.I Waqavakatoga', 'info.registry.people.L Rika', 'info.registry.people.L Samani', 'info.registry.people.L Vuadreu', 'info.registry.people.M Tilau', 'info.registry.people.M Vua', 'info.registry.people.R Kanai', 'info.registry.people.R Muriyalo', 'info.registry.people.S Lomani', 'info.registry.people.S Lote', 'info.registry.people.W Ofamoli', 'info.registry.people.Chinyenum George', 'info.registry.people.F Pessima', 'info.registry.people.L Piety', 'info.registry.people.Tyron Davies', 'info.registry.people.BK Ravi', 'info.registry.people.K Srinivasan', 'info.registry.people.NM Parween', 'info.registry.people.Kapila Kottahachchi', 'info.registry.people.S Ravikumar', 'info.registry.people.TC Mokorosi', 'info.registry.people.EJAPAM Jayasooriya', 'info.registry.people.Aina Najwa', 'info.registry.people.D Prakas', 'info.registry.people.JT Pooranakaran', 'info.registry.people.T Senthil Kumar', 'info.registry.people.Abdul Jabbar', 'info.registry.people.Asghar Ali Bhatti', 'info.registry.people.M Methtananda', 'info.registry.people.KKE Kannangara', 'info.registry.people.WMJK de Silva', 'info.registry.people.Mohammad Asif (2)', 'info.registry.people.NN Menon', 'info.registry.people.CA Numungu', 'info.registry.people.N Tsiame', 'info.registry.people.SE Aley', 'info.registry.people.HMNC Dhanasinghe', 'info.registry.people.G Ephraim', 'info.registry.people.H Ayoka', 'info.registry.people.L Agenburg', 'info.registry.people.RH Candy', 'info.registry.people.AP Venkata', 'info.registry.people.KA Heffernan', 'info.registry.people.H Roy', 'info.registry.people.AAIP Bastari', 'info.registry.people.BD Pare', 'info.registry.people.L Vua', 'info.registry.people.M Vuruna', 'info.registry.people.A Hogg', 'info.registry.people.Shathira Jakir', 'info.registry.people.Mohammad Rashid Ali Khan', 'info.registry.people.Riazuddin', 'info.registry.people.A Soni', 'info.registry.people.NL Bainton', 'info.registry.people.Tom Lungley', 'info.registry.people.C Kauripeke', 'info.registry.people.M Matobole', 'info.registry.people.TOW Chu', 'info.players.Norway', 'info.players.Sweden', 'info.registry.people.A Dastgir', 'info.registry.people.AS Gorad', 'info.registry.people.Abhilasha Singh', 'info.registry.people.Ayesha Hasan', 'info.registry.people.C Elmsjoo', 'info.registry.people.DS Gamage', 'info.registry.people.Farial Zia Safdar', 'info.registry.people.G Shukla', 'info.registry.people.Hina Hussain', 'info.registry.people.M Alugunoolla', 'info.registry.people.Mutaiba Ansar', 'info.registry.people.N Kayani', 'info.registry.people.Pooja Kumari', 'info.registry.people.R Immadi', 'info.registry.people.RG Somashekhar', 'info.registry.people.S Devata', 'info.registry.people.S Elmsjoo', 'info.registry.people.S Jadhav', 'info.registry.people.S Linden', 'info.registry.people.S Lundell', 'info.registry.people.S Raveendrakumar', 'info.registry.people.T Zilfidou', 'info.registry.people.HJ Thomas', 'info.players.South Korea', 'info.registry.people.Haliam Kwon', 'info.registry.people.Hee Jung Lee', 'info.registry.people.Hyejin Park', 'info.registry.people.Jiyeon Park', 'info.registry.people.Jiyeon Park (2)', 'info.registry.people.Kang Choi', 'info.registry.people.Mina Baek', 'info.registry.people.Seri Chang', 'info.registry.people.Seungmin Song', 'info.registry.people.Sinae Kim', 'info.registry.people.Su Jin Kim', 'info.registry.people.AE Smith', 'info.registry.people.AM Samaroo', 'info.registry.people.APC Kilowan', 'info.registry.people.AS Taai', 'info.registry.people.C van der Westhuizen', 'info.registry.people.CD Isaacs', 'info.registry.people.CJ Mitchley', 'info.registry.people.IH van Kerwel', 'info.registry.people.K Thomson', 'info.registry.people.GJ Davidson', 'info.registry.people.Emylia Eliani', 'info.registry.people.Ali Naqvi', 'info.registry.people.Gull Feroza', 'info.registry.people.Imran Javed', 'info.registry.people.Kiyo Fujikawa', 'info.registry.people.AG Dissanayake', 'info.registry.people.Fareeha Mehmood', 'info.registry.people.Ghulam Fatima', 'info.registry.people.P Dlamini', 'info.registry.people.J Sainda', 'info.registry.people.Han Guangze', 'info.registry.people.Shukhtara Rahman', 'info.registry.people.S Etim', 'info.registry.people.G Sharp', 'info.registry.people.Mofida Kocchargi', 'info.registry.people.JW Ogle-Thomas', 'info.registry.people.AL Hodgkinson', 'info.players.Cameroon', 'info.registry.people.AAM Eliane', 'info.registry.people.BMA Mbida', 'info.registry.people.CI Manidom', 'info.registry.people.DLN Kenfack', 'info.registry.people.JAN Ngono', 'info.registry.people.ME Bessala', 'info.registry.people.MFD Douma', 'info.registry.people.MLN Sissako', 'info.registry.people.MSF Tedjui', 'info.registry.people.MSN Ekani', 'info.registry.people.TMA Leslie', 'info.registry.people.L Kumari', 'info.registry.people.K Gray', 'info.registry.people.LP Mullapudi', 'info.registry.people.C Chatonzwa', 'info.registry.people.M Turay', 'info.registry.people.Lou Coulthard', 'info.registry.people.M Smook', 'info.registry.people.Tahir Shah', 'info.registry.people.V Mansale', 'info.registry.people.Shaffaa Saleem', 'info.registry.people.S Sandeepani', 'info.registry.people.Nadeem Malik', 'info.registry.people.M Carlot', 'info.registry.people.AR Maddela', 'info.registry.people.C Martin', 'info.registry.people.Kainat Qazi', 'info.registry.people.M Patel', 'info.registry.people.Mahewish Khan', 'info.registry.people.Maliha Baig', 'info.registry.people.Imtiaz Iqbal', 'info.registry.people.O Kirsten', 'info.players.Argentina', 'info.registry.people.A Stocks', 'info.registry.people.AT Nascimento', 'info.registry.people.C Sosa', 'info.registry.people.CA Greloni', 'info.registry.people.JC Cullen', 'info.registry.people.Jermaine Lindo', 'info.registry.people.L Iglesias', 'info.registry.people.L Taylor', 'info.registry.people.M Castineiras', 'info.registry.people.M Esquivel', 'info.registry.people.M Martinez', 'info.registry.people.T Basile', 'info.registry.people.V Vasquez', 'info.registry.people.CM Tuckett', 'info.registry.people.S Mannan', 'info.registry.people.CP Jack', 'info.registry.people.PY Lavine', 'info.registry.people.SK Tarapore', 'info.registry.people.Amna Jamal', 'info.registry.people.C Atkins', 'info.registry.people.SDNS Karunaratne', 'info.registry.people.A Williams', 'info.registry.people.P Chakraborty'
                    ], inplace = True)

# %%
cric.shape
# Out:
# (692, 12)

# %%
cric
# Out:
#                                               innings   info.city  \
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...      Murcia
# 0   [{'1st innings': {'team': 'India', 'deliveries...      Guyana
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...    Brisbane
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...         NaN
# 0   [{'1st innings': {'team': 'England', 'deliveri...       Derby
# ..                                                ...         ...
# 0   [{'1st innings': {'team': 'Barbados', 'deliver...  Birmingham
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...    Deventer
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...      Dublin
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...     Pokhara
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...         NaN
#
#       info.dates info.gender info.match_type  info.overs  \
# 0   [2019-06-27]      female             T20        20.0
# ...

# %%
cric['info.gender'].value_counts()
# Out:
# female    691
# Name: info.gender, dtype: int64

# %%
cric = cric[cric['info.gender'] == 'female']

# %%
cric['info.gender'].unique()
# Out:
# array(['female'], dtype=object)

# %%
cric.drop(columns = ['info.gender'], inplace = True)
cric
# Out:
# /tmp/ipykernel_3366/2411873997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cric.drop(columns = ['info.gender'], inplace = True)
#                                               innings   info.city  \
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...      Murcia
# 0   [{'1st innings': {'team': 'India', 'deliveries...      Guyana
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...    Brisbane
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...         NaN
# 0   [{'1st innings': {'team': 'England', 'deliveri...       Derby
# ..                                                ...         ...
# 0   [{'1st innings': {'team': 'Barbados', 'deliver...  Birmingham
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...    Deventer
# ...

# %%
cric['info.overs'].value_counts()
# Out:
# 20.0    691
# Name: info.overs, dtype: int64

# %%
cric['info.match_type'].value_counts()
# Out:
# T20    691
# Name: info.match_type, dtype: int64

# %%
cric.drop(columns = ['info.match_type'], inplace = True)
# Out:
# /tmp/ipykernel_3366/974554800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cric.drop(columns = ['info.match_type'], inplace = True)

# %%
cric
# Out:
#                                               innings   info.city  \
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...      Murcia
# 0   [{'1st innings': {'team': 'India', 'deliveries...      Guyana
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...    Brisbane
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...         NaN
# 0   [{'1st innings': {'team': 'England', 'deliveri...       Derby
# ..                                                ...         ...
# 0   [{'1st innings': {'team': 'Barbados', 'deliver...  Birmingham
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...    Deventer
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...      Dublin
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...     Pokhara
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...         NaN
#
#       info.dates  info.overs                info.teams info.toss.decision  \
# 0   [2019-06-27]        20.0   [Netherlands, Scotland]              field
# ...

# %%
import pickle
pickle.dump(cric, open('cric_data3.pkl', 'wb'))

# %%
matches = pickle.load(open('cric_data3.pkl', 'rb'))
matches
# Out:
#                                               innings   info.city  \
# 0   [{'1st innings': {'team': 'Scotland', 'deliver...      Murcia
# 0   [{'1st innings': {'team': 'India', 'deliveries...      Guyana
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...    Brisbane
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...         NaN
# 0   [{'1st innings': {'team': 'England', 'deliveri...       Derby
# ..                                                ...         ...
# 0   [{'1st innings': {'team': 'Barbados', 'deliver...  Birmingham
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...    Deventer
# 0   [{'1st innings': {'team': 'Ireland', 'deliveri...      Dublin
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...     Pokhara
# 0   [{'1st innings': {'team': 'Pakistan', 'deliver...         NaN
#
#       info.dates  info.overs                info.teams info.toss.decision  \
# 0   [2019-06-27]        20.0   [Netherlands, Scotland]              field
# ...

# %%
len(matches.iloc[0]['innings'])
# Out:
# 4

# %%
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'bowler': 'IJR Zwilling',
#    'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#    'non_striker': 'KE Bryce',
#    'batsman': 'SJ Bryce'}},
#  {0.2: {'bowler': 'IJR Zwilling',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'KE Bryce',
#    'batsman': 'SJ Bryce'}},
#  {0.3: {'non_striker': 'SJ Bryce',
#    'bowler': 'IJR Zwilling',
#    'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#    'extras': {'wides': 1},
#    'batsman': 'KE Bryce'}},
#  {0.4: {'non_striker': 'SJ Bryce',
#    'bowler': 'IJR Zwilling',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'KE Bryce'}},
#  {0.5: {'non_striker': 'SJ Bryce',
#    'bowler': 'IJR Zwilling',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'batsman': 'KE Bryce'}},
#  {0.6: {'non_striker': 'KE Bryce',
#    'bowler': 'IJR Zwilling',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'SJ Bryce'}},
#  {0.7: {'non_striker': 'KE Bryce',
# ...

# %%
count = 1
delivery = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [45, 75, 100, 150, 175, 180, 260, 450, 650, 780, 1000]:
        count += 1
        continue
    count += 1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for k in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(k)
            batsman.append(ball[k]['batsman'])
            bowler.append(ball[k]['bowler'])
            runs.append(ball[k]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[k]['wicket']['player_out'])
               
            except:
                player_of_dismissed.append('0')
             
    loop_df = pd.DataFrame({
        
            'match_id': match_id,
            'batting_team': batting_team,
            'teams': teams,
            'ball': ball_of_match,
            'batsman': batsman,
            'bowler': bowler,
            'runs': runs,
            'city': city,
            'venue': venue,
            'player_of_dismissed': player_of_dismissed
    })        
    
    delivery = delivery.append(loop_df)
# Out:
# /tmp/ipykernel_3366/2512052659.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery = delivery.append(loop_df)
# /tmp/ipykernel_3366/2512052659.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery = delivery.append(loop_df)
# /tmp/ipykernel_3366/2512052659.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery = delivery.append(loop_df)
# /tmp/ipykernel_3366/2512052659.py:49: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery = delivery.append(loop_df)
# ...

# %%
delivery
# Out:
#      match_id batting_team                    teams  ball     batsman  \
# 0           2     Scotland  [Netherlands, Scotland]   0.1    SJ Bryce
# 1           2     Scotland  [Netherlands, Scotland]   0.2    SJ Bryce
# 2           2     Scotland  [Netherlands, Scotland]   0.3    KE Bryce
# 3           2     Scotland  [Netherlands, Scotland]   0.4    KE Bryce
# 4           2     Scotland  [Netherlands, Scotland]   0.5    KE Bryce
# ..        ...          ...                      ...   ...         ...
# 117       692     Pakistan    [Pakistan, Sri Lanka]  19.2  Iram Javed
# 118       692     Pakistan    [Pakistan, Sri Lanka]  19.3  Sania Khan
# 119       692     Pakistan    [Pakistan, Sri Lanka]  19.4  Iram Javed
# 120       692     Pakistan    [Pakistan, Sri Lanka]  19.5  Sania Khan
# 121       692     Pakistan    [Pakistan, Sri Lanka]  19.6  Sania Khan
#
#            bowler  runs    city                     venue player_of_dismissed
# ...

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery['bowling_team'] = delivery.apply(bowl, axis = 1)

# %%
delivery
# Out:
#      match_id batting_team                    teams  ball     batsman  \
# 0           2     Scotland  [Netherlands, Scotland]   0.1    SJ Bryce
# 1           2     Scotland  [Netherlands, Scotland]   0.2    SJ Bryce
# 2           2     Scotland  [Netherlands, Scotland]   0.3    KE Bryce
# 3           2     Scotland  [Netherlands, Scotland]   0.4    KE Bryce
# 4           2     Scotland  [Netherlands, Scotland]   0.5    KE Bryce
# ..        ...          ...                      ...   ...         ...
# 117       692     Pakistan    [Pakistan, Sri Lanka]  19.2  Iram Javed
# 118       692     Pakistan    [Pakistan, Sri Lanka]  19.3  Sania Khan
# 119       692     Pakistan    [Pakistan, Sri Lanka]  19.4  Iram Javed
# 120       692     Pakistan    [Pakistan, Sri Lanka]  19.5  Sania Khan
# 121       692     Pakistan    [Pakistan, Sri Lanka]  19.6  Sania Khan
#
#            bowler  runs    city                     venue player_of_dismissed  \
# ...

# %%
delivery.drop(columns = ['teams'], inplace = True)

# %%
delivery['batting_team'].unique()
# Out:
# array(['Scotland', 'India', 'New Zealand', 'England', 'Botswana',
#        'Sierra Leone', 'South Africa', 'Bangladesh', 'Namibia',
#        'Pakistan', 'Australia', 'France', 'Ireland', 'Rwanda', 'Nepal',
#        'Sri Lanka', 'Germany', 'West Indies', 'Bahrain', 'Thailand',
#        'Uganda', 'Zimbabwe', 'Malaysia', 'Saudi Arabia',
#        'United Arab Emirates', 'Indonesia', 'Mozambique', 'Austria',
#        'Hong Kong', 'Kenya', 'United States of America',
#        'Papua New Guinea', 'Eswatini', 'Netherlands', 'Bhutan', 'Oman',
#        'Barbados', 'Japan', 'Tanzania', 'Maldives', 'Kuwait', 'Qatar',
#        'Vanuatu', 'Malawi', 'Canada', 'Nigeria', 'Singapore', 'Jersey',
#        'Mali', 'Lesotho', 'China', 'Fiji', 'Norway', 'Cameroon', 'Samoa',
#        'Argentina', 'Brazil'], dtype=object)

# %%
teams = ['Scotland', 'India', 'New Zealand', 'England',
        'South Africa', 'Bangladesh','Pakistan', 'Australia',
        'Ireland','Sri Lanka','West Indies','Netherlands']

# %%
delivery = delivery[delivery['batting_team'].isin( teams)]
delivery = delivery[delivery['bowling_team'].isin(teams)]

# %%
delivery['batting_team'] = delivery['batting_team'].replace(['West Indies'], 'Barbados')
delivery['bowling_team'] = delivery['bowling_team'].replace(['West Indies'], 'Barbados')

# %%
delivery
# Out:
#      match_id batting_team  ball     batsman        bowler  runs    city  \
# 0           2     Scotland   0.1    SJ Bryce  IJR Zwilling     2  Murcia
# 1           2     Scotland   0.2    SJ Bryce  IJR Zwilling     1  Murcia
# 2           2     Scotland   0.3    KE Bryce  IJR Zwilling     1  Murcia
# 3           2     Scotland   0.4    KE Bryce  IJR Zwilling     0  Murcia
# 4           2     Scotland   0.5    KE Bryce  IJR Zwilling     1  Murcia
# ..        ...          ...   ...         ...           ...   ...     ...
# 117       692     Pakistan  19.2  Iram Javed  LE Kaushalya     1     NaN
# 118       692     Pakistan  19.3  Sania Khan  LE Kaushalya     1     NaN
# 119       692     Pakistan  19.4  Iram Javed  LE Kaushalya     1     NaN
# 120       692     Pakistan  19.5  Sania Khan  LE Kaushalya     2     NaN
# 121       692     Pakistan  19.6  Sania Khan  LE Kaushalya     1     NaN
#
#                         venue player_of_dismissed bowling_team
# ...

# %%
out = delivery[['match_id', 'batting_team', 'bowling_team', 'runs', 'city', 'venue', 'ball', 'player_of_dismissed']]

# %%
out
# Out:
#      match_id batting_team bowling_team  runs    city  \
# 0           2     Scotland  Netherlands     2  Murcia
# 1           2     Scotland  Netherlands     1  Murcia
# 2           2     Scotland  Netherlands     1  Murcia
# 3           2     Scotland  Netherlands     0  Murcia
# 4           2     Scotland  Netherlands     1  Murcia
# ..        ...          ...          ...   ...     ...
# 117       692     Pakistan    Sri Lanka     1     NaN
# 118       692     Pakistan    Sri Lanka     1     NaN
# 119       692     Pakistan    Sri Lanka     1     NaN
# 120       692     Pakistan    Sri Lanka     2     NaN
# 121       692     Pakistan    Sri Lanka     1     NaN
#
#                         venue  ball player_of_dismissed
# 0    La Manga Club Top Ground   0.1                   0
# 1    La Manga Club Top Ground   0.2                   0
# 2    La Manga Club Top Ground   0.3                   0
# 3    La Manga Club Top Ground   0.4                   0
# ...

# %%
out['batting_team'].unique()
# Out:
# array(['Scotland', 'India', 'New Zealand', 'England', 'South Africa',
#        'Pakistan', 'Australia', 'Ireland', 'Sri Lanka', 'Barbados',
#        'Bangladesh', 'Netherlands'], dtype=object)

# %%
pickle.dump(out, open('cric_data4.pkl', 'wb'))
